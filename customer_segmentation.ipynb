# %%
 from google.colab import drive
drive.mount('/gdrive/')
# %cd /gdrive
# Out:
# Mounted at /gdrive/
# /gdrive

# %%
ls
# Out:
# MyDrive/  Shareddrives/

# %%
cd /gdrive/MyDrive/Customer_Segmentation
# Out:
# /gdrive/MyDrive/Customer_Segmentation

# %%
ls
# Out:
# Test.csv  Train.csv

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn import preprocessing
import warnings
warnings.filterwarnings("ignore")
import joblib

# %% [markdown]
# # Uploading Dataset

# %%
df_train=pd.read_csv('Train.csv')
df_train.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# 0  462809    Male           No   22        No     Healthcare              1.0
# 1  462643  Female          Yes   38       Yes       Engineer              NaN
# 2  466315  Female          Yes   67       Yes       Engineer              1.0
# 3  461735    Male          Yes   67       Yes         Lawyer              0.0
# 4  462669  Female          Yes   40       Yes  Entertainment              NaN
#
#   Spending_Score  Family_Size  Var_1 Segmentation
# 0            Low          4.0  Cat_4            D
# 1        Average          3.0  Cat_4            A
# 2            Low          1.0  Cat_6            B
# 3           High          2.0  Cat_6            B
# 4           High          6.0  Cat_6            A

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8068 entries, 0 to 8067
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               8068 non-null   int64
#  1   Gender           8068 non-null   object
#  2   Ever_Married     7928 non-null   object
#  3   Age              8068 non-null   int64
#  4   Graduated        7990 non-null   object
#  5   Profession       7944 non-null   object
#  6   Work_Experience  7239 non-null   float64
#  7   Spending_Score   8068 non-null   object
#  8   Family_Size      7733 non-null   float64
#  9   Var_1            7992 non-null   object
#  10  Segmentation     8068 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 693.5+ KB

# %%
df_train.describe().style.background_gradient(axis=0,cmap = 'RdYlGn')
# Out:
# <style type="text/css">
# #T_1b804_row0_col0 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_1b804_row0_col1, #T_1b804_row0_col2, #T_1b804_row0_col3, #T_1b804_row7_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_1b804_row1_col0, #T_1b804_row5_col0 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_1b804_row1_col1, #T_1b804_row1_col2, #T_1b804_row1_col3, #T_1b804_row2_col0, #T_1b804_row2_col1, #T_1b804_row2_col2, #T_1b804_row2_col3, #T_1b804_row3_col1, #T_1b804_row3_col2, #T_1b804_row3_col3, #T_1b804_row4_col1, #T_1b804_row4_col2, #T_1b804_row4_col3, #T_1b804_row5_col1, #T_1b804_row5_col2, #T_1b804_row5_col3, #T_1b804_row6_col2, #T_1b804_row6_col3, #T_1b804_row7_col2, #T_1b804_row7_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_1b804_row3_col0 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_1b804_row4_col0 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_1b804_row6_col0 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_1b804_row6_col1 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_1b804_row7_col1 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1b804_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ID</th>
#       <th class="col_heading level0 col1" >Age</th>
#       <th class="col_heading level0 col2" >Work_Experience</th>
#       <th class="col_heading level0 col3" >Family_Size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b804_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_1b804_row0_col0" class="data row0 col0" >8068.000000</td>
#       <td id="T_1b804_row0_col1" class="data row0 col1" >8068.000000</td>
#       <td id="T_1b804_row0_col2" class="data row0 col2" >7239.000000</td>
#       <td id="T_1b804_row0_col3" class="data row0 col3" >7733.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1b804_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_1b804_row1_col0" class="data row1 col0" >463479.214551</td>
#       <td id="T_1b804_row1_col1" class="data row1 col1" >43.466906</td>
#       <td id="T_1b804_row1_col2" class="data row1 col2" >2.641663</td>
#       <td id="T_1b804_row1_col3" class="data row1 col3" >2.850123</td>
#     </tr>
#     <tr>
#       <th id="T_1b804_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_1b804_row2_col0" class="data row2 col0" >2595.381232</td>
#       <td id="T_1b804_row2_col1" class="data row2 col1" >16.711696</td>
#       <td id="T_1b804_row2_col2" class="data row2 col2" >3.406763</td>
#       <td id="T_1b804_row2_col3" class="data row2 col3" >1.531413</td>
#     </tr>
#     <tr>
#       <th id="T_1b804_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_1b804_row3_col0" class="data row3 col0" >458982.000000</td>
#       <td id="T_1b804_row3_col1" class="data row3 col1" >18.000000</td>
#       <td id="T_1b804_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_1b804_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1b804_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_1b804_row4_col0" class="data row4 col0" >461240.750000</td>
#       <td id="T_1b804_row4_col1" class="data row4 col1" >30.000000</td>
#       <td id="T_1b804_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_1b804_row4_col3" class="data row4 col3" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1b804_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_1b804_row5_col0" class="data row5 col0" >463472.500000</td>
#       <td id="T_1b804_row5_col1" class="data row5 col1" >40.000000</td>
#       <td id="T_1b804_row5_col2" class="data row5 col2" >1.000000</td>
#       <td id="T_1b804_row5_col3" class="data row5 col3" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1b804_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_1b804_row6_col0" class="data row6 col0" >465744.250000</td>
#       <td id="T_1b804_row6_col1" class="data row6 col1" >53.000000</td>
#       <td id="T_1b804_row6_col2" class="data row6 col2" >4.000000</td>
#       <td id="T_1b804_row6_col3" class="data row6 col3" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1b804_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_1b804_row7_col0" class="data row7 col0" >467974.000000</td>
#       <td id="T_1b804_row7_col1" class="data row7 col1" >89.000000</td>
#       <td id="T_1b804_row7_col2" class="data row7 col2" >14.000000</td>
#       <td id="T_1b804_row7_col3" class="data row7 col3" >9.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # EDA

# %%
df_train.isna().sum()
# Out:
# ID                   0
# Gender               0
# Ever_Married       140
# Age                  0
# Graduated           78
# Profession         124
# Work_Experience    829
# Spending_Score       0
# Family_Size        335
# Var_1               76
# Segmentation         0
# dtype: int64

# %%
df_train.columns
# Out:
# Index(['ID', 'Gender', 'Ever_Married', 'Age', 'Graduated', 'Profession',
#        'Work_Experience', 'Spending_Score', 'Family_Size', 'Var_1',
#        'Segmentation'],
#       dtype='object')

# %%
columns = df_train.columns
binary_cols = []
remain_cols=[]
for col in columns:
    if df_train[col].value_counts().shape[0] == 2:
        binary_cols.append(col)
    else:
      remain_cols.append(col)

# %%
binary_cols
# Out:
# ['Gender', 'Ever_Married', 'Graduated']

# %%
Ever_Married_numeric = {'No':1,'Yes':0}
df_train.Ever_Married.replace(Ever_Married_numeric, inplace=True)

# %%
Gender_numeric = {'Male':1,'Female':0}
df_train.Gender.replace(Gender_numeric, inplace=True)

# %%
Graduated_numeric = {'No':1,'Yes':0}
df_train.Graduated.replace(Graduated_numeric, inplace=True)

# %%
Profession_numeric = {'Homemaker':8,'Marketing':7,'Executive':6,'Lawyer':5,'Doctor':4,'Engineer':3,'Entertainment':2,'Healthcare':1,'Artist':0}
df_train.Profession.replace(Profession_numeric, inplace=True)

# %%
Spending_Score_numeric = {'High':2,'Average':1,'Low':0}
df_train.Spending_Score.replace(Spending_Score_numeric, inplace=True)

# %%
Var_1_numeric = {'Cat_7':6,'Cat_6':5,'Cat_5':4,'Cat_4':3,'Cat_3':2,'Cat_2':1,'Cat_1':0}
df_train.Var_1.replace(Var_1_numeric, inplace=True)

# %%
df_train['Ever_Married'].fillna(value =df_train['Ever_Married'].mean() , inplace = True)
df_train['Graduated'].fillna(value =df_train['Graduated'].mean() , inplace = True)
df_train['Profession'].fillna(value =df_train['Profession'].mean() , inplace = True)
df_train['Work_Experience'].fillna(value =df_train['Work_Experience'].mean() , inplace = True)
df_train['Family_Size'].fillna(value =df_train['Family_Size'].mean() , inplace = True)
df_train['Var_1'].fillna(value =df_train['Var_1'].mean() , inplace = True)

# %%
sns.countplot("Family_Size", data=df_train)

# %%
sns.countplot("Graduated", data=df_train)

# %%
plt.figure(figsize=(12,9),dpi = 100)
sns.heatmap(df_train.corr(),vmax=.8,annot = True, square = True)
plt.show()

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
cData_attr = df_train.iloc[:, 0:7]
sns.pairplot(cData_attr, diag_kind='kde')

# %%
X = df_train.drop(['Type'], axis = 1)
Y = df_train["Type"]
x_Data = X.values
y_Data = Y.values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_Data, y_Data, test_size = 0.2, random_state = 42)

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
model.score(X_test,y_test)
# Out:
# 0.9625

# %%
from sklearn.model_selection import cross_val_score
print(cross_val_score(GaussianNB(),X_train, y_train, cv=5))
# Out:
# [0.90625  0.921875 0.953125 0.921875 0.953125]

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
pred = model.predict(X_train) 
accuracy_score(y_train, pred)
# Out:
# 0.940625

# %%
confusion_matrix(y_train, pred)
# Out:
# array([[  8,   3,   0,   0,   1,   0,   0],
#        [  0,  12,   0,   0,   0,   9,   0],
#        [  0,   0,  47,   0,   0,   0,   0],
#        [  0,   0,   1,  12,   0,   0,   0],
#        [  0,   0,   0,   0,   9,   3,   0],
#        [  1,   1,   0,   0,   0, 196,   0],
#        [  0,   0,   0,   0,   0,   0,  17]])

# %%
predicted_test = model.predict(X_test)
p=accuracy_score(y_test, predicted_test)

# %%
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score

# %%
print(classification_report(y_test, predicted_test))
# Out:
#                                precision    recall  f1-score   support
#
#             Basilar-type aura       1.00      1.00      1.00         6
#  Familial hemiplegic migraine       1.00      1.00      1.00         3
#         Migraine without aura       1.00      1.00      1.00        13
#                         Other       1.00      1.00      1.00         4
#  Sporadic hemiplegic migraine       0.33      0.50      0.40         2
#    Typical aura with migraine       0.98      0.96      0.97        49
# Typical aura without migraine       1.00      1.00      1.00         3
#
#                      accuracy                           0.96        80
#                     macro avg       0.90      0.92      0.91        80
#                  weighted avg       0.97      0.96      0.97        80

# %%
cma = confusion_matrix(y_test, predicted_test)

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(cma, cmap=plt.cm.Blues, alpha=0.3)
for i in range(cma.shape[0]):
    for j in range(cma.shape[1]):
        ax.text(x=j, y=i,s=cma[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()

# %% [markdown]
# # Random forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier as rf

# %%
clf_forest = rf(n_estimators=100, max_depth=10)
clf_forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10)

# %%
pred = clf_forest.predict(X_train)
accuracy_score(y_train, pred)
# Out:
# 0.96875

# %%
confusion_matrix(y_train, pred)
# Out:
# array([[ 12,   0,   0,   0,   0,   0,   0],
#        [  0,  14,   0,   0,   0,   7,   0],
#        [  0,   0,  47,   0,   0,   0,   0],
#        [  0,   0,   1,  12,   0,   0,   0],
#        [  0,   0,   0,   0,  10,   2,   0],
#        [  0,   0,   0,   0,   0, 198,   0],
#        [  0,   0,   0,   0,   0,   0,  17]])

# %%
pred_test = clf_forest.predict(X_test)
q=accuracy_score(y_test, pred_test)

# %%
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score

# %%
print(classification_report(y_test, pred_test))
# Out:
#                                precision    recall  f1-score   support
#
#             Basilar-type aura       1.00      0.50      0.67         6
#  Familial hemiplegic migraine       1.00      0.33      0.50         3
#         Migraine without aura       0.87      1.00      0.93        13
#                         Other       1.00      0.75      0.86         4
#  Sporadic hemiplegic migraine       0.00      0.00      0.00         2
#    Typical aura with migraine       0.89      0.98      0.93        49
# Typical aura without migraine       1.00      1.00      1.00         3
#
#                      accuracy                           0.89        80
#                     macro avg       0.82      0.65      0.70        80
#                  weighted avg       0.89      0.89      0.87        80

# %%
cma = confusion_matrix(y_test, pred_test)

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(cma, cmap ="coolwarm_r", alpha=0.3)
for i in range(cma.shape[0]):
    for j in range(cma.shape[1]):
        ax.text(x=j, y=i,s=cma[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn import tree

# %%
 clf = tree.DecisionTreeClassifier()
 clf = clf.fit(X_train, y_train)

# %%
pred1 = clf.predict(X_train)
accuracy_score(y_train, pred1)
# Out:
# 1.0

# %%
confusion_matrix(y_train, pred1)
# Out:
# array([[ 12,   0,   0,   0,   0,   0,   0],
#        [  0,  21,   0,   0,   0,   0,   0],
#        [  0,   0,  47,   0,   0,   0,   0],
#        [  0,   0,   0,  13,   0,   0,   0],
#        [  0,   0,   0,   0,  12,   0,   0],
#        [  0,   0,   0,   0,   0, 198,   0],
#        [  0,   0,   0,   0,   0,   0,  17]])

# %%
pred1_test = clf.predict(X_test)
r=accuracy_score(y_test, pred1_test)

# %%
print(classification_report(y_test, pred1_test))
# Out:
#                                precision    recall  f1-score   support
#
#             Basilar-type aura       0.71      0.83      0.77         6
#  Familial hemiplegic migraine       0.00      0.00      0.00         3
#         Migraine without aura       0.81      1.00      0.90        13
#                         Other       0.00      0.00      0.00         4
#  Sporadic hemiplegic migraine       0.25      0.50      0.33         2
#    Typical aura with migraine       0.96      0.96      0.96        49
# Typical aura without migraine       1.00      1.00      1.00         3
#
#                      accuracy                           0.86        80
#                     macro avg       0.53      0.61      0.57        80
#                  weighted avg       0.82      0.86      0.84        80

# %%
cma = confusion_matrix(y_test, pred1_test)

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(cma, cmap ="coolwarm_r", alpha=0.3)
for i in range(cma.shape[0]):
    for j in range(cma.shape[1]):
        ax.text(x=j, y=i,s=cma[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression  
clf1= LogisticRegression(random_state=0)  
clf1.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
pred_LR= clf1.predict(X_train)
accuracy_score(y_train, pred_LR)
# Out:
# 0.934375

# %%
confusion_matrix(y_train, pred_LR)
# Out:
# array([[  9,   1,   1,   0,   0,   1,   0],
#        [  0,  12,   0,   0,   0,   9,   0],
#        [  0,   0,  47,   0,   0,   0,   0],
#        [  0,   0,   1,  10,   0,   2,   0],
#        [  0,   0,   2,   0,   6,   4,   0],
#        [  0,   0,   0,   0,   0, 198,   0],
#        [  0,   0,   0,   0,   0,   0,  17]])

# %%
pred_LR_test = clf1.predict(X_test)
s=accuracy_score(y_test, pred_LR_test)

# %%
print(classification_report(y_test, pred_LR_test))
# Out:
#                                precision    recall  f1-score   support
#
#             Basilar-type aura       1.00      0.67      0.80         6
#  Familial hemiplegic migraine       1.00      1.00      1.00         3
#         Migraine without aura       1.00      1.00      1.00        13
#                         Other       0.80      1.00      0.89         4
#  Sporadic hemiplegic migraine       0.50      0.50      0.50         2
#    Typical aura with migraine       0.96      0.98      0.97        49
# Typical aura without migraine       1.00      1.00      1.00         3
#
#                      accuracy                           0.95        80
#                     macro avg       0.89      0.88      0.88        80
#                  weighted avg       0.95      0.95      0.95        80

# %%
cma = confusion_matrix(y_test, pred_LR_test)

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(cma, cmap ="coolwarm_r", alpha=0.3)
for i in range(cma.shape[0]):
    for j in range(cma.shape[1]):
        ax.text(x=j, y=i,s=cma[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()

# %% [markdown]
# # Neural networks

# %%
from sklearn.neural_network import MLPClassifier

# %%
clf2= MLPClassifier(solver='lbfgs', alpha=1e-5,
           hidden_layer_sizes=(5, 2), random_state=1)
clf2.fit(X_train, y_train)
# Out:
# MLPClassifier(alpha=1e-05, hidden_layer_sizes=(5, 2), random_state=1,
#               solver='lbfgs')

# %%
pred_NN= clf2.predict(X_train)
accuracy_score(y_train, pred_NN)
# Out:
# 0.61875

# %%
confusion_matrix(y_train, pred_NN)
# Out:
# array([[  0,   0,   0,   0,   0,  12,   0],
#        [  0,   0,   0,   0,   0,  21,   0],
#        [  0,   0,   0,   0,   0,  47,   0],
#        [  0,   0,   0,   0,   0,  13,   0],
#        [  0,   0,   0,   0,   0,  12,   0],
#        [  0,   0,   0,   0,   0, 198,   0],
#        [  0,   0,   0,   0,   0,  17,   0]])

# %%
pred_NN_test = clf2.predict(X_test)
u=accuracy_score(y_test, pred_NN_test)

# %%
print(classification_report(y_test, pred_NN_test))
# Out:
#                                precision    recall  f1-score   support
#
#             Basilar-type aura       0.00      0.00      0.00         6
#  Familial hemiplegic migraine       0.00      0.00      0.00         3
#         Migraine without aura       0.00      0.00      0.00        13
#                         Other       0.00      0.00      0.00         4
#  Sporadic hemiplegic migraine       0.00      0.00      0.00         2
#    Typical aura with migraine       0.61      1.00      0.76        49
# Typical aura without migraine       0.00      0.00      0.00         3
#
#                      accuracy                           0.61        80
#                     macro avg       0.09      0.14      0.11        80
#                  weighted avg       0.38      0.61      0.47        80

# %%
cma = confusion_matrix(y_test, pred_NN_test)

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(cma, cmap ="prism", alpha=0.3)
for i in range(cma.shape[0]):
    for j in range(cma.shape[1]):
        ax.text(x=j, y=i,s=cma[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()

# %% [markdown]
# # XGBOOST

# %%
import xgboost as xgb

# %%
xgb = xgb.XGBClassifier()
xgb.fit(X_train,y_train)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
pred_XGB= xgb.predict(X_train)
accuracy_score(y_train, pred_XGB)
# Out:
# 0.984375

# %%
confusion_matrix(y_train, pred_XGB)
# Out:
# array([[ 12,   0,   0,   0,   0,   0,   0],
#        [  0,  19,   0,   0,   0,   2,   0],
#        [  0,   0,  47,   0,   0,   0,   0],
#        [  0,   0,   1,  12,   0,   0,   0],
#        [  0,   0,   0,   0,  10,   2,   0],
#        [  0,   0,   0,   0,   0, 198,   0],
#        [  0,   0,   0,   0,   0,   0,  17]])

# %%
pred_XGB_test = xgb.predict(X_test)
v=accuracy_score(y_test, pred_XGB_test)

# %%
print(classification_report(y_test, pred_XGB_test))
# Out:
#                                precision    recall  f1-score   support
#
#             Basilar-type aura       0.75      0.50      0.60         6
#  Familial hemiplegic migraine       0.50      0.67      0.57         3
#         Migraine without aura       0.93      1.00      0.96        13
#                         Other       1.00      0.75      0.86         4
#  Sporadic hemiplegic migraine       0.00      0.00      0.00         2
#    Typical aura with migraine       0.94      0.98      0.96        49
# Typical aura without migraine       1.00      1.00      1.00         3
#
#                      accuracy                           0.90        80
#                     macro avg       0.73      0.70      0.71        80
#                  weighted avg       0.89      0.90      0.89        80

# %%
cma = confusion_matrix(y_test, pred_XGB_test)

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(cma, cmap ="prism", alpha=0.3)
for i in range(cma.shape[0]):
    for j in range(cma.shape[1]):
        ax.text(x=j, y=i,s=cma[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()

# %% [markdown]
# # Comparative predicting

# %%
import numpy as np
import matplotlib.pyplot as plt
# creating the dataset
data = {'NB':p, 'RF':q, 'DT':r,'LR':s,'NN':u,'XGB':v}
courses = list(data.keys())
values = list(data.values())
fig = plt.figure(figsize = (10, 6))
# creating the bar plot
plt.bar(courses, values, color ='crimson',
		width = 0.4)
plt.xlabel("Algorithms")
plt.ylabel("Accuracy")
plt.title("Comparitive analysis of algorithm on the basis of the acccuracy")
plt.show()

# %%
activities = ['NB', 'RF', 'DT', 'LR','NN','XGB'] 
# portion covered by each label
slices = [p,q,r,s,u,v]
 
# color for each label
colors = ['red', 'blue', 'green','yellow','black','crimson']
 
# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0, 0, 0.1,0,0.1,0),
        radius = 1.2, autopct = '%1.1f%%')
 
# plotting legend
plt.legend()
 
# showing the plot
plt.show()

# %% [markdown]
# # Model saving

# %%
filename = 'naive_bayes.sav'
joblib.dump(model, filename)
filename1 = 'random_forest_Classifier.sav'
joblib.dump(clf_forest, filename1)
filename2 = 'decision_tree_classifier.sav'
joblib.dump(clf, filename2)
filename3 = 'logistic_regression.sav'
joblib.dump(clf1, filename3)
filename4 = 'neural_networks.sav'
joblib.dump(clf2, filename4)
filename5 = 'XGBOOST.sav'
joblib.dump(xgb, filename5)
# Out:
# ['XGBOOST.sav']
